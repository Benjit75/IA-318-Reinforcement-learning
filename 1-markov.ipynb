# %% [markdown]
# # Reinforcement Learning
#
# # 1. Markov Decision Process
#
# This notebook presents some examples of Markov Decison Processes, where an **agent** interacts with its **environment** and collects **rewards**.
#
# In all considered models, rewards are attached to reached **states**. In games for instance, the reward of a state is +1 if you win, -1 if you loose, 0 in all other cases.

# %%
import numpy as np

# %%
# %matplotlib notebook

# %%
from model import Walk, Maze

# %% [markdown]
# Each model is an object of the class ``Environment`` storing the current state.

# %%
from model import Environment

# %%
methods_environment = [method for method in dir(Environment) if '__' not in method]

# %%
methods_environment
# Out:
# ['decode',
#  'display',
#  'encode',
#  'get_actions',
#  'get_all_actions',
#  'get_all_states',
#  'get_model',
#  'get_reward',
#  'get_transition',
#  'init_state',
#  'is_game',
#  'is_terminal',
#  'reinit_state',
#  'step']

# %% [markdown]
# The agent interacts with the environment and collects rewards.

# %%
from agent import Agent

# %%
methods_agent = [method for method in dir(Agent) if '__' not in method]

# %%
methods_agent
# Out:
# ['get_action',
#  'get_actions',
#  'get_episode',
#  'get_gains',
#  'one_step_policy',
#  'random_policy']

# %% [markdown]
# ## Walk
#
# We start with a walk in a square. Some states (to be found) have positive rewards. Some wind (unknown) disturbs the walk.

# %%
# environment
model = Walk()

# %%
model.display()
# Out:
# <div id='b14f1e33-9162-45c3-958e-13a8c2ca75e1'></div>

# %%
model.Size
# Out:
# (5, 5)

# %%
# rewards (to be discovered)
model.Rewards
# Out:
# {(1, 1): 1, (1, 3): -1, (3, 1): -1, (3, 3): 3}

# %%
# wind (move probabilities)
model.Wind
# Out:
# {(0, 1): 0.1, (1, 0): 0.2}

# %%
state = model.state

# %%
state
# Out:
# array([0, 0])

# %%
model.get_actions(state)
# Out:
# [(0, 1), (1, 0)]

# %%
action = (0, 1)

# %%
model.step(action)
# Out:
# (0, False)

# %%
model.state
# Out:
# array([0, 2])

# %%
model.display()
# Out:
# <div id='23f8c2df-a9d3-42b3-a71f-e303a1217860'></div>

# %%
# agent with random policy (default)
agent = Agent(model)

# %%
state = model.state
action = agent.get_action(state)

# %%
state
# Out:
# array([0, 2])

# %%
action
# Out:
# (0, 1)

# %%
# interaction with the environment
reward, stop = model.step(action)

# %%
reward
# Out:
# -1

# %%
stop
# Out:
# False

# %%
# all possible actions
agent.get_actions(state)
# Out:
# [(0, 1), (0, -1), (1, 0)]

# %%
# policy of the agent
probs, actions = agent.policy(state)

# %%
print(probs)
# Out:
# [0.33333333 0.33333333 0.33333333]

# %%
print(actions)
# Out:
# [(0, 1), (0, -1), (1, 0)]

# %%
# an episode
stop, states, rewards = agent.get_episode(horizon=50)

# %%
# the episode includes the initial state
len(states)
# Out:
# 51

# %%
# display
animation = model.display(states)
# Out:
# <div id='cb5f11f2-10b6-4761-9ecc-da4ee8eb5af2'></div>

# %%
animation
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgc56e391276c84af585ccf2f77e39a19f">
#   <div class="anim-controls">
#     <input id="_anim_sliderc56e391276c84af585ccf2f77e39a19f" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animc56e391276c84af585ccf2f77e39a19f.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animc56e391276c84af585ccf2f77e39a19f.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animc56e391276c84af585ccf2f77e39a19f.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animc56e391276c84af585ccf2f77e39a19f.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animc56e391276c84af585ccf2f77e39a19f.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animc56e391276c84af585ccf2f77e39a19f.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animc56e391276c84af585ccf2f77e39a19f.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animc56e391276c84af585ccf2f77e39a19f.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animc56e391276c84af585ccf2f77e39a19f.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animc56e391276c84af585ccf2f77e39a19f.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectc56e391276c84af585ccf2f77e39a19f"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_c56e391276c84af585ccf2f77e39a19f"
#              checked>
#       <label for="_anim_radio1_c56e391276c84af585ccf2f77e39a19f">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_c56e391276c84af585ccf2f77e39a19f"
#              >
#       <label for="_anim_radio2_c56e391276c84af585ccf2f77e39a19f">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_c56e391276c84af585ccf2f77e39a19f"
#              >
#       <label for="_anim_radio3_c56e391276c84af585ccf2f77e39a19f">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc56e391276c84af585ccf2f77e39a19f";
#     var slider_id = "_anim_sliderc56e391276c84af585ccf2f77e39a19f";
#     var loop_select_id = "_anim_loop_selectc56e391276c84af585ccf2f77e39a19f";
#     var frames = new Array(51);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/MnkTPAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpA

# %%
# initial reward = 0 by convention
len(rewards)
# Out:
# 51

# %%
np.sum(rewards)
# Out:
# -7

# %%
# gains from initial state, with discount factor
gains = agent.get_gains(n_runs=10, horizon=100, gamma=0.9)

# %%
np.mean(gains)
# Out:
# 1.927580697804619

# %% [markdown]
# ## To do

# %% [markdown]
# * Test the weighted random policy where the probability of each move is proportional to its weight.
# * Is this policy better than the (pure) random policy?

# %%
weights = {(0, 1): 2, (1, 0): 2, (0, -1): 1, (-1, 0): 1}

# %%
def weighted_random_policy(state, weights=weights):
    actions = Walk().get_actions(state)
    # to be modified
    probs = np.array([weights.get(action, 0) for action in actions])
    probs = probs / np.sum(probs)
    
    return probs, actions

# %%
agent = Agent(model, policy=weighted_random_policy)

# %%
# test the policy
probs, actions = agent.policy(model.state)
print(probs)
print(actions)
# an episode
stop, states, rewards = agent.get_episode(horizon=50)
# display
animation = model.display(states)
animation
# initial reward = 0 by convention
print(len(rewards))
print(np.sum(rewards))
# gains from initial state, with discount factor
gains = agent.get_gains(n_runs=10, horizon=100, gamma=0.9)
print(np.mean(gains))
# Out:
# [0.5 0.5]
# [(0, -1), (-1, 0)]
# 51
# 9
# 0.5646807552340195

# %% [markdown]
# ## Maze
#
# Now let's try to escape a maze!

# %%
maze_map = np.load('maze.npy')

# %%
init_state = (1, 0)
exit_state = (1, 20)
Maze.set_parameters(maze_map, init_state, [exit_state])

# %%
model = Maze()

# %%
model.display()

# %%
model.state
# Out:
# array([1, 0])

# %%
state = model.state
reward = model.get_reward(state)

# %%
# -1 in any state except the exit
reward
# Out:
# -1

# %%
model.get_actions(state)
# Out:
# [(0, 1)]

# %%
action = (0, 1)

# %%
model.step(action)
# Out:
# (-1, False)

# %%
model.display()

# %%
# agent with random policy
agent = Agent(model)

# %%
stop, states, rewards = agent.get_episode(horizon=200)

# %%
animation = model.display(states)

# %%
animation
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img8b3d437f6a6e4c5d8e6fdb5c6c05350a">
#   <div class="anim-controls">
#     <input id="_anim_slider8b3d437f6a6e4c5d8e6fdb5c6c05350a" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim8b3d437f6a6e4c5d8e6fdb5c6c05350a.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim8b3d437f6a6e4c5d8e6fdb5c6c05350a.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim8b3d437f6a6e4c5d8e6fdb5c6c05350a.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim8b3d437f6a6e4c5d8e6fdb5c6c05350a.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim8b3d437f6a6e4c5d8e6fdb5c6c05350a.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim8b3d437f6a6e4c5d8e6fdb5c6c05350a.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim8b3d437f6a6e4c5d8e6fdb5c6c05350a.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim8b3d437f6a6e4c5d8e6fdb5c6c05350a.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim8b3d437f6a6e4c5d8e6fdb5c6c05350a.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim8b3d437f6a6e4c5d8e6fdb5c6c05350a.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select8b3d437f6a6e4c5d8e6fdb5c6c05350a"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_8b3d437f6a6e4c5d8e6fdb5c6c05350a"
#              checked>
#       <label for="_anim_radio1_8b3d437f6a6e4c5d8e6fdb5c6c05350a">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_8b3d437f6a6e4c5d8e6fdb5c6c05350a"
#              >
#       <label for="_anim_radio2_8b3d437f6a6e4c5d8e6fdb5c6c05350a">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_8b3d437f6a6e4c5d8e6fdb5c6c05350a"
#              >
#       <label for="_anim_radio3_8b3d437f6a6e4c5d8e6fdb5c6c05350a">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img8b3d437f6a6e4c5d8e6fdb5c6c05350a";
#     var slider_id = "_anim_slider8b3d437f6a6e4c5d8e6fdb5c6c05350a";
#     var loop_select_id = "_anim_loop_select8b3d437f6a6e4c5d8e6fdb5c6c05350a";
#     var frames = new Array(201);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjQuMywgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy/MnkTPAAAACXBIWXMAAAsT\
# AAALEwEAmpwY

# %%
# time in the Maze
-np.sum(rewards)
# Out:
# 201

# %% [markdown]
# ## To do

# %% [markdown]
# * Test the weighted random policy.
# * Which choice of the weights looks the best for this maze?

# %% [markdown]
# ## Games
#
# Finally, let's play games!<br>
# Note that in most games:
# * you play against an adversary (which is part of the environment),
# * you may play first or second,
# * when your adversary plays, you have only one possible action (let your adversary play),
# * you can also impose an action to your adversary (useful for training).
#
# We here consider [Tic-Tac-Toe](https://en.wikipedia.org/wiki/Tic-tac-toe), [Nim](https://en.wikipedia.org/wiki/Nim), [Connect Four](https://en.wikipedia.org/wiki/Connect_Four) and [Five in a row](https://en.wikipedia.org/wiki/Gomoku).
# Feel free to add more :-)

# %%
from model import TicTacToe, Nim, ConnectFour, FiveInRow

# %% [markdown]
# Each game is an object of the class ``Game``.

# %%
from model import Game

# %%
methods_game = [method for method in dir(Game) if '__' not in method]

# %%
methods_game

# %% [markdown]
# The method ``get_next_state`` allows you to get the next state for any (state, action) pair, without modifying the current state. This will be useful to learn good policies.
#
# The method ``get_available_actions`` gives the available actions, ignoring the player.

# %%
set(methods_game) - set(methods_environment)

# %% [markdown]
# ## Tic-Tac-Toe

# %% [markdown]
# We start with Tic-Tac-Toe.

# %% [markdown]
# ### Play first

# %%
# game against a random player (default)
game = TicTacToe()

# %%
game.display()

# %%
# next player, board
game.state

# %%
# your possible actions
game.get_actions(game.state)

# %%
# next state given some move
game.get_next_state(game.state, (1,1))

# %%
# the state is not modified
game.state

# %%
# you play at random (default)
agent = Agent(game)

# %%
# you play as player 1 (default)
agent.player

# %%
# your adversary plays as player -1
game.adversary.player

# %%
state = game.state
action = agent.get_action(state)

# %%
action

# %%
reward, stop = game.step(action)

# %%
# you're blue
game.display()

# %%
game.state

# %%
# all possible moves
game.get_actions(game.state)

# %%
# your moves (not your turn)
agent.get_actions(game.state)

# %%
action = agent.get_action(game.state)

# %%
print(action)

# %%
reward, stop = game.step(action)

# %%
game.display()

# %%
stop, states, rewards = agent.get_episode()

# %%
animation = game.display(states)

# %%
animation

# %%
rewards

# %%
gains = agent.get_gains()
np.unique(agent.get_gains(), return_counts=True)

# %% [markdown]
# ### Play second

# %%
# your adversary starts
game = TicTacToe(play_first=False)

# %%
game.first_player

# %%
# you still play at random
agent = Agent(game)

# %%
stop, states, rewards = agent.get_episode()

# %%
animation = game.display(states)

# %%
# you're still blue, red starts
animation

# %%
rewards

# %%
gains = agent.get_gains()
np.unique(agent.get_gains(), return_counts=True)

# %% [markdown]
# ### Control your adversary
#
# You can force the actions of your adversary (useful for training).

# %%
game = TicTacToe()

# %%
actions = [(0, 0), (1, 1), (0, 2),  (2, 2), (0, 1)]

# %%
for action in actions:
    game.step(action)

# %%
game.display()

# %% [markdown]
# ### One step ahead

# %%
# your adversary is random
game = TicTacToe()

# %%
# you play with one-step ahead policy
agent = Agent(game, policy='one_step')

# %%
stop, states, rewards = agent.get_episode()

# %%
animation = game.display(states)

# %%
animation

# %%
gains = agent.get_gains()
np.unique(agent.get_gains(), return_counts=True)

# %%
# your adversary also looks one-step ahead
game = TicTacToe(adversary_policy='one_step')

# %%
agent = Agent(game, policy='one_step')

# %%
stop, states, rewards = agent.get_episode()

# %%
animation = game.display(states)

# %%
animation

# %%
np.unique(agent.get_gains(), return_counts=True)

# %% [markdown]
# ## Nim

# %% [markdown]
# ### Random players

# %%
# game against a random player (default)
game = Nim()

# %%
game.state

# %%
game.display()

# %%
# player, board
game.state

# %%
# you play at random
agent = Agent(game)

# %%
state = game.state
action = agent.get_action(state)

# %%
action

# %%
reward, stop = game.step(action)

# %%
game.display()

# %%
stop, states, rewards = agent.get_episode()

# %%
animation = game.display(states)

# %%
animation

# %%
rewards

# %%
np.unique(agent.get_gains(), return_counts=True)

# %% [markdown]
# ### One step ahead

# %%
game = Nim(adversary_policy='one_step')

# %%
agent = Agent(game, policy='one_step')

# %%
np.unique(agent.get_gains(), return_counts=True)

# %% [markdown]
# ## Connect Four

# %% [markdown]
# ### Random players

# %%
# game against a random player
game = ConnectFour()

# %%
game.display()

# %%
game.state

# %%
# you play at random
agent = Agent(game)

# %%
stop, states, rewards = agent.get_episode()

# %%
animation = game.display(states)

# %%
# you play yellow
animation

# %%
np.unique(agent.get_gains(n_runs=10), return_counts=True)

# %% [markdown]
# ### One step ahead

# %%
game = ConnectFour(adversary_policy='one_step')

# %%
agent = Agent(game, policy='one_step')

# %%
stop, states, rewards = agent.get_episode()

# %%
animation = game.display(states)

# %%
animation

# %%
np.unique(agent.get_gains(n_runs=10), return_counts=True)

# %% [markdown]
# ## Five-in-a-row

# %% [markdown]
# ### Random players

# %%
game = FiveInRow()

# %%
game.display()

# %%
agent = Agent(game)

# %%
stop, states, rewards = agent.get_episode()

# %%
animation = game.display(states)

# %%
animation

# %%
np.unique(agent.get_gains(n_runs=10), return_counts=True)

# %% [markdown]
# ### One step ahead

# %%
game = FiveInRow()

# %%
agent = Agent(game, policy='one_step')

# %%
np.unique(agent.get_gains(n_runs=5), return_counts=True)

# %%
# a better adversary
game = FiveInRow(adversary_policy='one_step')

# %%
agent = Agent(game, policy='one_step')

# %%
np.unique(agent.get_gains(n_runs=5), return_counts=True)

# %% [markdown]
# ## Value function
#
# The value function of a policy can be computed from Bellman's equation, provided the state space is not too large.

# %% [markdown]
# You can check this condition by listing all states.

# %%
model = Walk()

# %%
len(model.get_all_states())

# %% [markdown]
# ## To do
#
# * Complete the method ``evaluate_policy`` of the class ``PolicyEvaluation``.
# * Evaluate the random policy in the ``Walk`` model and display the value function.
# * Observe the impact of the wind on the value function.
# * Display the value function of the random policy in the maze.

# %%
# we use sparse transition matrices
from scipy import sparse

# %%
class PolicyEvaluation:
    """Evaluation of a policy by Bellman's equation.
    
    Parameters
    ----------
    model: object of class Environment
        Model.
    policy: function
        Policy of the agent.
    player: int
        Player for games (1 or -1, default = default player of the game).
    gamma: float
        Discount factor (between 0 and 1).
    n_eval: int
        Number of iterations of Bellman's equation for policy evaluation.
    """
    def __init__(self, model, policy='random', player=None, gamma=1, n_eval=100):
        self.model = model
        agent = Agent(model, policy)
        self.policy = agent.policy
        if player is None:
            if model.is_game():
                self.player = model.player
            else:
                self.player = 1
        else:
            self.player = player
        self.gamma = gamma
        self.n_eval = n_eval
        self.index_states()
        self.get_rewards()
        self.actions = self.model.get_all_actions()
        self.get_transitions()
        
    def index_states(self):
        """Index all states."""
        self.states = self.model.get_all_states()
        self.n_states = len(self.states)
        self.state_id = {self.model.encode(state): i for i, state in enumerate(self.states)}
        
    def get_state_id(self, state):
        code = self.model.encode(state)
        return self.state_id[code]

    def get_rewards(self):
        """Get the reward of each state."""
        rewards = np.zeros(self.n_states)
        for i, state in enumerate(self.states):    
            rewards[i] = self.model.get_reward(state)
        self.rewards = rewards
        
    def get_actions(self, state):
        actions = self.model.get_actions(state)
        return actions
    
    def get_transitions(self):
        """Get the transitions (probabilities to move from one state to another) for each action."""
        transition = {action: sparse.lil_matrix((self.n_states, self.n_states)) for action in self.actions}
        for i, state in enumerate(self.states):    
            actions = self.get_actions(state)
            for action in actions:
                try:
                    probs, next_states = self.model.get_transition(state, action)
                    indices = np.array([self.get_state_id(next_state) for next_state in next_states])
                    transition[action][i, indices] = np.array(probs)
                except:
                    print(state, actions, action)
        self.transition = {action: sparse.csr_matrix(transition[action]) for action in self.actions}
            
    def evaluate_policy(self):
        """Evaluate a policy by iteration of Bellman's equation."""
        transition = self.transition
        rewards = self.rewards
        # probability of each action over the states
        probs = {action: np.zeros(self.n_states) for action in self.actions}
        for state in self.states:    
            i = self.get_state_id(state)
            for prob, action in zip(*self.policy(state)):
                probs[action][i] = prob
        # Bellman's equation
        values = np.zeros(self.n_states)
        for t in range(self.n_eval):
            new_values = np.zeros(self.n_states)
            for action in self.actions:
                # to be modified
                new_values += 0
            values = new_values.copy()
        self.values = values

# %%
model = Walk()
agent = Agent(model)
random_policy = agent.policy

# %%
algo = PolicyEvaluation(model, random_policy, gamma=0.9)

# %%
algo.evaluate_policy()

# %%
values = algo.values

# %%
model.display_values(values)

# %%
wind = {(0, 1): 0.75}
Walk.set_parameters(Walk.Size, Walk.Rewards, wind)

# %%
model = Walk()

# %% [markdown]
# ## To do
#
# * Evaluate the random policy and the one-step policy in some games, when possible.
# * Do the same when the adversary plays with the one-step policy.
# * Predict some first good moves for each of these game.

# %%
Game = TicTacToe
game = Game()

# %%
algo = PolicyEvaluation(game)
